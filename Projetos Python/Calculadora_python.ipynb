# %%
import math as mt


parada=1
while(parada!='s'):
    print(10*'*'+'Python Calculator'+10*'*' + '\n'  'Selecione o número da opção desejada:')
    print('1 - Soma' '\n' '2 - Subtração' '\n' '3 - Multiplicação' '\n' '4 - Divisão' '\n' '5 - Seno' '\n' '6 - Cosseno' '\n' '7 - Tangente' '\n' '8 - Potenciação' '\n' '9 - Raiz quadrada' '\n' '10 - Fatorial' )

    operacao = int(input('Digite sua opção (1 - 10): '))

    if operacao == 1:
        dig1 = float(input('Digite o primeiro número: '))
        dig2 = float(input('Digite o segundo número: '))
        resultado = dig1 + dig2
        print(f'O resultado da Soma entre {dig1} e {dig2} é {resultado}')
        
    elif operacao == 2:
        dig1 = float(input('Digite o primeiro número: '))
        dig2 = float(input('Digite o segundo número: '))
        resultado = dig1-dig2
        print(f'O resultado da Subtração entre {dig1} e {dig2} é {resultado}')

    elif operacao == 3:
        dig1 = float(input('Digite o primeiro número: '))
        dig2 = float(input('Digite o segundo número: '))
        resultado = dig1*dig2
        print(f'O resultado da Multiplicação entre {dig1} e {dig2} é {resultado}')

    elif operacao == 4:
        dig1 = float(input('Digite o primeiro número: '))
        dig2 = float(input('Digite o segundo número: '))
        resultado = dig1/dig2
        print(f'O resultado da Divisão entre {dig1} e {dig2} é {resultado}')

    elif operacao == 5:
        dig1 = float(input('Digite o primeiro número: '))
        resultado = mt.sin(mt.radians(dig1))
        print(f'O resultado do seno de {dig1} em radianos é {resultado:.2f}')

    elif operacao == 6:
        dig1 = float(input('Digite o primeiro número: '))
        resultado = mt.cos(mt.radians(dig1))
        print(f'O resultado do cosseno de {dig1} em radianos é {resultado:.2f}')

    elif operacao == 7:
        dig1 = float(input('Digite o primeiro número: '))
        resultado = mt.tan(mt.radians(dig1))
        print(f'O resultado da tangente de {dig1} em radianos é {resultado:.2f}')

    elif operacao == 8:
        dig1 = float(input('Digite o primeiro número (base): '))
        dig2 = float(input('Digite o segundo número (expoente): '))
        resultado = mt.pow(dig1, dig2)
        print(f'O resultado de {dig1} elevado a {dig2} é {resultado:.2f}')
        
    elif operacao == 9:
        dig1 = float(input('Digite o primeiro número: '))
        resultado = mt.sqrt(dig1)
        print(f'O resultado da raiz quadrada de {dig1} é {resultado:.2f}')
        
    elif operacao == 10:
        dig1 = float(input('Digite o primeiro número: '))
        resultado = mt.factorial(dig1)
        print(f'O resultado do fatorial de {dig1} é {resultado:.2f}')

    else:
        print('Opção inválida!')    
    parada = input('Digite s para parar : ')

# %%
import math as mt
parada=1
parada2=''
while(parada!='s'):
    print(10*'*'+'Python Calculator'+10*'*' + '\n'  'Selecione o número da opção desejada:')
    print('1 - Soma' '\n' '2 - Subtração')

    operacao = int(input('Digite sua opção (1 - 10): '))

    if operacao == 1:
        dig1 = float(input('Digite o primeiro número: '))
        dig2 = float(input('Digite o segundo número: '))
        resultado=dig1+dig2
        print(f'O resultado da Soma entre {dig1} e {dig2} é {resultado}')

        
    elif operacao == 2:
        dig1 = float(input('Digite o primeiro número: '))
        dig2 = float(input('Digite o segundo número: '))
        resultado=dig1-dig2
        print(f'O resultado da Subtração entre {dig1} e {dig2} é {resultado}')
        
    else:
        print('Opção inválida!')   
    parada = input('Digite s para parar : ')
    if parada!='s':
      cond=int(input("Deseja utilizar o resultado anterior nas operações [1-sim,2-Não continuar sem,3-parar]"))
      if cond==1:
        while(True):
          print(f"Seu resultado foi: {resultado}")
          print("O que você quer fazer com ele?")
          print('1 - Soma' '\n' '2 - Subtração')
          operacao = int(input('Digite sua opção (1 - 10): '))

          if operacao == 1:
            dig1 = float(input('Digite o primeiro número: '))
            resultado2=resultado+dig1
            print(f'O resultado da Soma entre {resultado} e {dig1} é {resultado2}')

          
          elif operacao == 2:
            dig1 = float(input('Digite o primeiro número: '))
            resultado2=resultado-dig1
            print(f'O resultado da Subtração entre {resultado} e {dig1} é {resultado2}')

          parada2=input('s para ir para o menu principal, n para continuar outras operações com o resultado')
          if parada2=='s' or cond==2:
            break  
    if cond==3:
      break

# %%
import math as mt
parada=1
parada2=''
while(parada!='s'):
    print(10*'*'+'Python Calculator'+10*'*' + '\n'  'Selecione o número da opção desejada:')
    print('1 - Soma' '\n' '2 - Subtração' '\n' '3 - Multiplicação' '\n' '4 - Divisão' '\n' '5 - Seno' '\n' '6 - Cosseno' '\n' '7 - Tangente' '\n' '8 - Potenciação' '\n' '9 - Raiz quadrada' '\n' '10 - Fatorial' )

    operacao = int(input('Digite sua opção (1 - 10): '))

    if operacao == 1:
        dig1 = float(input('Digite o primeiro número: '))
        dig2 = float(input('Digite o segundo número: '))
        resultado=dig1+dig2
        print(f'O resultado da Soma entre {dig1} e {dig2} é {resultado}')

        
    elif operacao == 2:
        dig1 = float(input('Digite o primeiro número: '))
        dig2 = float(input('Digite o segundo número: '))
        resultado=dig1-dig2
        print(f'O resultado da Subtração entre {dig1} e {dig2} é {resultado}')
    elif operacao == 3:
        dig1 = float(input('Digite o primeiro número: '))
        dig2 = float(input('Digite o segundo número: '))
        resultado = dig1*dig2
        print(f'O resultado da Multiplicação entre {dig1} e {dig2} é {resultado}')

    elif operacao == 4:
        dig1 = float(input('Digite o primeiro número: '))
        dig2 = float(input('Digite o segundo número: '))
        resultado = dig1/dig2
        print(f'O resultado da Divisão entre {dig1} e {dig2} é {resultado}')

    elif operacao == 5:
        dig1 = float(input('Digite o primeiro número: '))
        resultado = mt.sin(mt.radians(dig1))
        print(f'O resultado do seno de {dig1} em radianos é {resultado:.2f}')

    elif operacao == 6:
        dig1 = float(input('Digite o primeiro número: '))
        resultado = mt.cos(mt.radians(dig1))
        print(f'O resultado do cosseno de {dig1} em radianos é {resultado:.2f}')

    elif operacao == 7:
        dig1 = float(input('Digite o primeiro número: '))
        resultado = mt.tan(mt.radians(dig1))
        print(f'O resultado da tangente de {dig1} em radianos é {resultado:.2f}')

    elif operacao == 8:
        dig1 = float(input('Digite o primeiro número (base): '))
        dig2 = float(input('Digite o segundo número (expoente): '))
        resultado = mt.pow(dig1, dig2)
        print(f'O resultado de {dig1} elevado a {dig2} é {resultado:.2f}')
        
    elif operacao == 9:
        dig1 = float(input('Digite o primeiro número: '))
        resultado = mt.sqrt(dig1)
        print(f'O resultado da raiz quadrada de {dig1} é {resultado:.2f}')
        
    elif operacao == 10:
        dig1 = float(input('Digite o primeiro número: '))
        resultado = mt.factorial(dig1)
        print(f'O resultado do fatorial de {dig1} é {resultado:.2f}')            
    else:
        print('Opção inválida!')   
    parada = input('Digite s para parar : ')
    if parada!='s':
      cond=int(input("Deseja utilizar o resultado anterior nas operações [1-sim,2-Não continuar sem,3-parar]"))
      if cond==1:
        while(True):
          print(f"Seu resultado foi: {resultado}")
          print("O que você quer fazer com ele?")
          print('1 - Soma' '\n' '2 - Subtração' '\n' '3 - Multiplicação' '\n' '4 - Divisão' '\n' '5 - Seno' '\n' '6 - Cosseno' '\n' '7 - Tangente' '\n' '8 - Potenciação' '\n' '9 - Raiz quadrada' '\n' '10 - Fatorial' )
          operacao = int(input('Digite sua opção (1 - 10): '))

          if operacao == 1:
            dig1 = float(input('Digite o primeiro número: '))
            resultado2=resultado+dig1
            print(f'O resultado da Soma entre {resultado} e {dig1} é {resultado2}')

          
          elif operacao == 2:
            dig1 = float(input('Digite o primeiro número: '))
            resultado2=resultado-dig1
            print(f'O resultado da Subtração entre {resultado} e {dig1} é {resultado2}')

          elif operacao == 3:
            dig1 = float(input('Digite o primeiro número: '))
            resultado2 = dig1*resultado
            print(f'O resultado da Multiplicação entre {dig1} e {resultado} é {resultado2}')

          elif operacao == 4:
              dig1 = float(input('Digite o primeiro número: '))
              resultado2 = resultado/dig1
              print(f'O resultado da Divisão entre {resultado} e {dig1} é {resultado2}')

          elif operacao == 5:
              
              resultado2 = mt.sin(mt.radians(resultado))
              print(f'O resultado do seno de {resultado} em radianos é {resultado2:.2f}')

          elif operacao == 6:
            
              resultado2 = mt.cos(mt.radians(resultado))
              print(f'O resultado do cosseno de {resultado} em radianos é {resultado2:.2f}')

          elif operacao == 7:
              
              resultado2 = mt.tan(mt.radians(resultado))
              print(f'O resultado da tangente de {resultado} em radianos é {resultado2:.2f}')

          elif operacao == 8:
              
              dig1 = float(input('Digite o segundo número (expoente): '))
              resultado2 = mt.pow(resultado, dig1)
              print(f'O resultado de {resultado} elevado a {dig1} é {resultado2:.2f}')
              
          elif operacao == 9:
             
              resultado2 = mt.sqrt(resultado)
              print(f'O resultado da raiz quadrada de {resultado} é {resultado2:.2f}')
              
          elif operacao == 10:
              
              resultado2 = mt.factorial(resultado)
              print(f'O resultado do fatorial de {resultado} é {resultado2:.2f}')            
          else:
              print('Opção inválida!') 


          parada2=input('s para ir para o menu principal, n para continuar outras operações com o resultado')
          if parada2=='s' or cond==2:
            break  
    if cond==3:
      break
